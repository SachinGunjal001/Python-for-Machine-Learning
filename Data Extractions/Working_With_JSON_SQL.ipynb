# %%
import pandas as pd

# %%
df = pd.read_json('train.json')
df.head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %%
pd.read_json('https://github.com/campusx-official/100-days-of-machine-learning/blob/main/day16%20-%20working-with-json-and-sql')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pd.read_json('https://github.com/campusx-official/100-days-of-machine-learning/blob/main/day16%20-%20working-with-json-and-sql')
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\json\_json.py:1014, in JsonReader.read(self)
#    1012         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1013 else:
# ...
