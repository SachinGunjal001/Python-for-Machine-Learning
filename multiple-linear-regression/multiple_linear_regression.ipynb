# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)  # create dataset

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.shape
# Out:
# (100, 3)

# %%
df.head()
# Out:
#    feature1  feature2     target
# 0 -0.579828  1.352413 -67.171597
# 1  1.742854 -1.011875  51.911558
# 2  0.606858  0.513691  10.286087
# 3  0.493891 -2.511237  35.167887
# 4  1.236989 -0.650127  -9.330772

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# MAE 30.406085687204886
# MSE 1305.329002804093
# R2 score 0.7100010444314102

# %%
# ...existing code...
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(x, y)

# build prediction input (100 x 2) BEFORE calling predict
final = np.column_stack((xGrid.ravel(), yGrid.ravel()))

# predict and reshape to the meshgrid shape
z_final = lr.predict(final).reshape(xGrid.shape)

z = z_final

fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')
fig.add_trace(go.Surface(x=x, y=y, z=z))
fig.show()
# ...existing code...

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.add_trace(go.Surface(x = x, y = y, z =z ))

fig.show()

# %%
lr.coef_
# Out:
# array([47.74405023, 25.18057088])

# %%
lr.intercept_
# Out:
# np.float64(-3.396193303229796)
