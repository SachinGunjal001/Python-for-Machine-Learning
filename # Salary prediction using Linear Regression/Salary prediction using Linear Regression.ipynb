# %% [markdown]
# # Salary prediction using Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('SalaryData.csv')
df
# Out:
#        YoE    Salary
# 0      5.0   90000.0
# 1      3.0   65000.0
# 2     15.0  150000.0
# 3      7.0   60000.0
# 4     20.0  200000.0
# ...    ...       ...
# 6699  20.0  200000.0
# 6700   3.0   50000.0
# 6701   4.0   55000.0
# 6702  14.0  140000.0
# 6703   1.0   35000.0
#
# [6704 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   YoE     6701 non-null   float64
#  1   Salary  6699 non-null   float64
# dtypes: float64(2)
# memory usage: 104.9 KB

# %%
df = df.dropna()

x = df[['YoE']]
y = df['Salary']

# %%
sns.displot(df['Salary'])

# %%
sns.displot(df['YoE'])

# %%
df.corr()
# Out:
#              YoE    Salary
# YoE     1.000000  0.808969
# Salary  0.808969  1.000000

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

LinReg  = LinearRegression()
LinReg.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred = LinReg.predict(x_test)
y_pred
# Predicted value from Linear regression mode
# Out:
# array([178078.33694265,  86470.34847029,  72376.81178223, ...,
#         79423.58012626, 149891.26356654, 213312.17866278], shape=(1340,))

# %%
y_test
# actual value
# Out:
# 1269    200000.0
# 5734     70000.0
# 1787     65000.0
# 422     155000.0
# 4691     50000.0
#           ...
# 6133     75000.0
# 4982    170000.0
# 4716     55000.0
# 3075    147326.0
# 2551    182237.0
# Name: Salary, Length: 1340, dtype: float64

# %%
LinReg.predict([[2.5],[3],[10],[7.5],[0]])
# Out:
# array([ 75900.19595425,  79423.58012626, 128750.95853445, 111134.03767439,
#         58283.27509418])

# %%
sns.regplot(x = df['YoE'], y=df['Salary'] )
# Out:
# <Axes: xlabel='YoE', ylabel='Salary'>
